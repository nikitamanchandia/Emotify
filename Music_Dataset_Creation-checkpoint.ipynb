# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv('data_moods.csv')

# %%
df.head()
# Out:
#                                           name                        album  \
# 0                                         1999                         1999
# 1                                           23                           23
# 2                                     9 Crimes                            9
# 3                               99 Luftballons               99 Luftballons
# 4  A Boy Brushed Red Living In Black And White  They're Only Chasing Safety
#
#            artist                      id release_date  popularity  length  \
# 0          Prince  2H7PHVdQ3mXqEHXcvclTB0   1982-10-27          68  379266
# 1  Blonde Redhead  4HIwL9ii9CcXpTOTzMq0MP   2007-04-16          43  318800
# 2     Damien Rice  5GZEeowhvSieFDiR8fQ2im   2006-11-06          60  217946
# 3            Nena  6HA97v4wEGQ5TUClRM0XLc   1984-08-21           2  233000
# 4       Underoath  47IWLfIKOKhFnz1FUEUIkE   2004-01-01          60  268000
#
# ...

# %%
df.columns
# Out:
# Index(['name', 'album', 'artist', 'id', 'release_date', 'popularity', 'length',
#        'danceability', 'acousticness', 'energy', 'instrumentalness',
#        'liveness', 'valence', 'loudness', 'speechiness', 'tempo', 'key',
#        'time_signature', 'mood'],
#       dtype='object')

# %%
df[['name','mood']]
# Out:
#                                             name       mood
# 0                                           1999      Happy
# 1                                             23        Sad
# 2                                       9 Crimes        Sad
# 3                                 99 Luftballons      Happy
# 4    A Boy Brushed Red Living In Black And White  Energetic
# ..                                           ...        ...
# 681                                  windcatcher       Calm
# 682              yellow is the color of her eyes        Sad
# 683                           you broke me first        Sad
# 684                          you were good to me        Sad
# 685                                         æfre       Calm
#
# [686 rows x 2 columns]

# %%
sns.countplot(df['mood'])

# %%
happy=[]
sad=[]
neutral=[]
for i in range(len(df)) :
    if df.loc[i,"mood"]=="Happy":
        happy.append(df.loc[i,"name"]+" artist:"+df.loc[i,"artist"])
    elif df.loc[i,"mood"]=="Sad":
        sad.append(df.loc[i,"name"]+" artist:"+df.loc[i,"artist"])
    elif df.loc[i,"mood"]=="Calm":
        neutral.append(df.loc[i,"name"]+" artist:"+df.loc[i,"artist"])

# %%
happy
# Out:
# ['1999 artist:Prince',
#  '99 Luftballons artist:Nena',
#  'A Little Less Conversation - JXL Radio Edit Remix artist:Elvis Presley',
#  'Africa artist:TOTO',
#  'All or Nothing (feat. Axel Ehnström) - Deluxe Mix artist:Lost Frequencies',
#  'Anthem artist:EDX',
#  'Are You Gonna Be My Girl artist:Jet',
#  'Beautiful Life artist:Lost Frequencies',
#  'Bennie And The Jets - Remastered 2014 artist:Elton John',
#  'Better Together artist:Jack Johnson',
#  'Blow artist:Yves V',
#  'Body Rock artist:Bingo Players',
#  'Bottom Of The Sea artist:Isaac Elton',
#  'Brimful of Asha - Norman Cook Remix artist:Fatboy Slim',
#  'Butterfly artist:Crazy Town',
#  "California Dreamin' artist:The Mamas & The Papas",
#  'Chocolate artist:The 1975',
#  'Clap Your Hands artist:Sia',
#  'Come On Eileen artist:Dexys Midnight Runners',
#  "Count On You - ATFC's C-thru Remix artist:Autoerotique",
#  'Crash artist:Chris Malinchak',
#  'Crazy artist:Gnarls Barkley',
#  'Crazy Horses artist:The Osmonds',
# ...

# %%
sad
# Out:
# ['23 artist:Blonde Redhead',
#  '9 Crimes artist:Damien Rice',
#  'Algo Rhythm artist:One Sentence. Supervisor',
#  'Alison artist:Slowdive',
#  'All I Want artist:Kodaline',
#  'All Mirrors artist:Angel Olsen',
#  'All of Me artist:John Legend',
#  'Anchor artist:Novo Amor',
#  'Andromeda artist:Weyes Blood',
#  "Angel's Song artist:Arlo Parks",
#  'Ashes to Ashes artist:Warpaint',
#  'Bad Feeling artist:Muzz',
#  'Bad Kingdom artist:May',
#  'Bad Timing artist:Arlo Day',
#  'Ballad of the Dying Man artist:Father John Misty',
#  'Be My Mistake artist:The 1975',
#  'Before You Go artist:Lewis Capaldi',
#  'Better Than Today artist:Rhys Lewis',
#  'Bird artist:Billie Marten',
#  'Bison on the Plains artist:Grandaddy',
#  'Black Car artist:Beach House',
#  'Bloodbuzz Ohio artist:SOAK',
#  'Bloom Innocent artist:Fink',
#  'Breathe Me artist:Sia',
#  'Bruises artist:Lewis Capaldi',
#  'Chariot artist:Beach House',
#  'Cold Arms artist:Mumford & Sons',
# ...

# %%
neutral
# Out:
# ['A Burden to Bear artist:Emmanuelle Rimbaud',
#  'A La Plage artist:Ron Adelaar',
#  'Adjustments artist:Josie Mehlin',
#  'Adrift artist:Cooper Sams',
#  'After The Rain artist:Comet Blue',
#  'Ambre artist:Nils Frahm',
#  'Anaviosi artist:Alexi Musnitsky',
#  'Atlavík artist:Hugar',
#  'Auburn Sky artist:Toledo Rains',
#  'Awaken artist:William Duhamel',
#  'Back+ artist:Ton Snijders',
#  'Balloon artist:YuMe',
#  'Bayybe 07 artist:Bilo 503',
#  'Beekweide artist:Job Roggeveen',
#  'Betty artist:Wilson Trouvé',
#  'Bloom artist:Hilder Sky',
#  'Bortom Träden artist:Erik Reno',
#  'Bouquet with Lilies artist:La Acacia',
#  'Breathe artist:Hans Voller',
#  'Bye Bye Little House artist:Ella van der Woude',
#  'Calm Wilderness artist:Night Sounds',
#  'City Lights artist:Marlies du Mosch',
#  'Cleansing artist:Jacco Wynia',
#  'Clear Skies artist:Dhyana Thomas',
#  'Coda artist:Jakob Ahlbom',
#  'Colgando artist:Barulinho',
#  'Collapse Into Light artist:Evin Iris',
# ...
